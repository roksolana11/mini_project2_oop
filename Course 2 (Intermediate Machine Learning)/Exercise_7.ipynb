# %% [markdown]
# Step 1: The Data Science of Shoelaces

# %% [markdown]
# Yes, the “leather used” feature constitutes data leakage in this context. It is a perfect proxy for the number of shoes produced in the current month, which directly determines the number of shoelaces needed. However, at the time of prediction, this information would not yet be available, since it refers to the current month’s production. Therefore, including it gives the model access to future information.
#
# It only would not be leakage if the goal were a retrospective analysis where the amount of leather used is already known.

# %% [markdown]
# Step 2: Return of the Shoelaces

# %% [markdown]
# This reduces the risk of data leakage, but it depends on when the “leather ordered” information becomes available.
#
# If the amount of leather ordered is known before or at the start of the month (i.e., it reflects decisions made using only past information), then it is a valid feature and does not cause data leakage.
#
# However, if the orders are placed or adjusted using information from the current month’s production or demand, then it could still leak future information and introduce data leakage.

# %% [markdown]
# Step 3: Getting Rich With Cryptocurrencies?

# %% [markdown]
# No, he is not right.
#
# There is likely a serious problem with data leakage or unrealistic feature construction in his model. Several of the features he is using (such as current price, short-term price changes, and trading volume over the last 24 hours) may include information that would not actually be fully available at the time the prediction is made, or may indirectly contain future information depending on how they are computed.
#
# Additionally, even if there is no leakage, a very low error (less than $1) despite large real price fluctuations is a strong warning sign that the model is too good to be true.
#
# Finally, accurately predicting price does not necessarily mean the model can reliably predict price direction or produce profitable trading signals, so using it as an investment strategy is still very risky.

# %% [markdown]
# Step 4: Preventing Infections

# %% [markdown]
# Yes, this can cause both target leakage and train-test contamination if the surgeon infection rates are calculated using the full dataset.
#
# It becomes leakage because the feature is directly derived from the target (infection). It causes train-test contamination if information from the test set is used when computing these rates.
#
# It is only safe if the infection rates are computed using the training data only and then applied to the validation/test sets.

# %% [markdown]
# Step 5: Housing Prices

# %%
# Fill in the line below with one of 1, 2, 3 or 4.
potential_leakage_feature = 2

# Check your answer
q_5.check()

# %% [markdown]
# 2 is the source of target leakage. Here is an analysis for each feature:
#
# The size of a house is unlikely to be changed after it is sold (though technically it's possible). But typically this will be available when we need to make a prediction, and the data won't be modified after the home is sold. So it is pretty safe.
#
# We don't know the rules for when this is updated. If the field is updated in the raw data after a home was sold, and the home's sale is used to calculate the average, this constitutes a case of target leakage. At an extreme, if only one home is sold in the neighborhood, and it is the home we are trying to predict, then the average will be exactly equal to the value we are trying to predict. In general, for neighborhoods with few sales, the model will perform very well on the training data. But when you apply the model, the home you are predicting won't have been sold yet, so this feature won't work the same as it did in the training data.
#
# These don't change, and will be available at the time we want to make a prediction. So there's no risk of target leakage here.
#
# This also doesn't change, and it is available at the time we want to make a prediction. So there's no risk of target leakage here.
